# %%
import numpy as np
data=np.load("t_data_.npz",allow_pickle=True)

# %%
train=data["train"]

# %%
import numpy as np
data=np.load("t_data_.npz",all)

# %%
train.shape
# Out:
# (17423, 3)

# %%
# import cv2
import matplotlib.pyplot as plt
image_no=15590
img,acceleration,steering=0,1,2
print(train[image_no][steering])
plt.imshow(train[image_no][img])
train[image_no][img].shape
# Out:
# 0.00999999999999944
# (224, 224, 3)

# %%
w=224
k=5
p=0
s=2

# %%
(((w-k+(2*p))/s)+1)
# Out:
# 110.5
